# %% [markdown]
# Dans ce notebook, nous allons étudier le fait qu'il y ait une différence de prix pour les jours 0, 1 et 2 entre mobile=1 et mobile=0.
#
# => Résultat à retrouver !
# Prix plus élevé quand mobile=1

# %% [markdown]
# # Import librairies et données

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/train/train_set.csv") # issu du notebook req_api
df_vienna = pd.read_csv("../data/clean/vienna.csv")
df_vilnius = pd.read_csv("../data/clean/vilnius.csv")
df_amsterdam = pd.read_csv("../data/clean/amsterdam.csv")
df_rome = pd.read_csv("../data/clean/rome.csv")
df_valletta = pd.read_csv("../data/clean/valletta.csv")
df_paris = pd.read_csv("../data/clean/paris.csv")
df_madrid = pd.read_csv("../data/clean/madrid.csv")
df_copenhagen = pd.read_csv("../data/clean/copenhagen.csv")
df_sofia = pd.read_csv("../data/clean/sofia.csv")
df_hung = pd.concat([df_vienna, df_vilnius, df_amsterdam, df_rome, df_valletta, df_paris, df_madrid, df_copenhagen, df_sofia])

# %%
display(df_hung)
display(df)
# Out:
#       hotel_id  price  stock    city  date   language  mobile  avatar_id  \
# 0          890     76      0  vienna     0  hungarian       0     295268
# 1          875    103      0  vienna     0  hungarian       0     295268
# 2          336    123      0  vienna     0  hungarian       0     295268
# 3          173    107      0  vienna     0  hungarian       0     295268
# 4          315    286      0  vienna     0  hungarian       0     295268
# ...        ...    ...    ...     ...   ...        ...     ...        ...
# 2413       578     85    196   sofia    44  hungarian       0     295222
# 2414       883     87    192   sofia    44  hungarian       0     295222
# 2415       107     40     55   sofia    44  hungarian       0     295222
# 2416       899     72    138   sofia    44  hungarian       0     295222
# 2417       597    125    283   sofia    44  hungarian       0     295222
#
#      avatar_name
# 0         99S11K
# 1         99S11K
# 2         99S11K
# 3         99S11K
# 4         99S11K
# ...          ...
# 2413      P959MX
# 2414      P959MX
# 2415      P959MX
# 2416      P959MX
# 2417      P959MX
#
# [43266 rows x 9 columns]
#         hotel_id  price  stock     city  date    language  mobile  avatar_id  \
# 0            768    286     13   madrid    11  portuguese       0     155051
# 1            126     96      8   madrid    11  portuguese       0     155051
# 2            378    124      0   madrid    11  portuguese       0     155051
# 3            351     91      4   madrid    11  portuguese       0     155051
# 4            747    172     15   madrid    11  portuguese       0     155051
# ...          ...    ...    ...      ...   ...         ...     ...        ...
# 166832       503    277      4  vilnius     5  lithuanian       0     267714
# 166833       240    224      4  vilnius     5  lithuanian       0     267714
# 166834       820    207      4  vilnius     5  lithuanian       0     267714
# 166835       288    113      0  vilnius     5  lithuanian       0     267714
# 166836       136    107      3  vilnius     5  lithuanian       0     267714
#
#        avatar_name  order_requests
# 0           8HOAWS               1
# 1           8HOAWS               1
# 2           8HOAWS               1
# 3           8HOAWS               1
# 4           8HOAWS               1
# ...            ...             ...
# 166832      9HJM3R            1566
# 166833      9HJM3R            1566
# 166834      9HJM3R            1566
# 166835      9HJM3R            1566
# 166836      9HJM3R            1566
#
# [166837 rows x 10 columns]

# %%
# Renommage colonnes df_hung et jointure avec celui du train où le language=hungarian
df_hung = df_hung.rename(columns={"price": "price_hung", "stock": "stock_hung", "mobile": "mobile_hung",
                       "avatar_id": "avatar_id_hung", "avatar_name": "avatar_name_hung"})
# display(df_hung)

df_ = df[(df['language']=='hungarian')&(df['mobile']==1)]
# display(df_)

df_comp = df_.merge(df_hung, how='left', on=['hotel_id', 'date'])
display(df_comp)
# Out:
#       hotel_id  price  stock city_x  date language_x  mobile  avatar_id  \
# 0          714     70     19   rome    30  hungarian       1     156582
# 1          112     70     22   rome    30  hungarian       1     156582
# 2          486    157     66   rome    30  hungarian       1     156582
# 3          642     66     31   rome    30  hungarian       1     156582
# 4          751    200    122   rome    30  hungarian       1     156582
# ...        ...    ...    ...    ...   ...        ...     ...        ...
# 4565       141     85      0  sofia     1  hungarian       1     267703
# 4566       181    100      0  sofia     1  hungarian       1     267703
# 4567       923     53      0  sofia     1  hungarian       1     267703
# 4568       862     74      0  sofia     1  hungarian       1     267703
# 4569       683     85      0  sofia     1  hungarian       1     267703
#
#      avatar_name  order_requests  price_hung  stock_hung city_y language_y  \
# 0         0D28CG              89          70          19   rome  hungarian
# 1         0D28CG              89          70          22   rome  hungarian
# 2         0D28CG              89         157          66   rome  hungarian
# 3         0D28CG              89          66          31   rome  hungarian
# 4         0D28CG              89         200         122   rome  hungarian
# ...          ...             ...         ...         ...    ...        ...
# 4565      JYYYYE            1555          85           0  sofia  hungarian
# 4566      JYYYYE            1555         100           0  sofia  hungarian
# 4567      JYYYYE            1555          53           0  sofia  hungarian
# 4568      JYYYYE            1555          74           0  sofia  hungarian
# 4569      JYYYYE            1555          85           0  sofia  hungarian
#
#       mobile_hung  avatar_id_hung avatar_name_hung
# 0               0          295163           RUT5FY
# 1               0          295163           RUT5FY
# 2               0          295163           RUT5FY
# 3               0          295163           RUT5FY
# 4               0          295163           RUT5FY
# ...           ...             ...              ...
# 4565            0          295179           ZF1A8I
# 4566            0          295179           ZF1A8I
# 4567            0          295179           ZF1A8I
# 4568            0          295179           ZF1A8I
# 4569            0          295179           ZF1A8I
#
# [4570 rows x 17 columns]

# %% [markdown]
# # Calcul du prix moyen par date selon mobile = 0 et selon mobile = 1

# %%
df_prices_hung = df_comp[['date', 'price_hung']]
# display(df_prices_hung)

# calcul des prix moyen par date 
## mobile = 0
print("mobile=0")
df_prices_mean_hung = df_prices_hung.groupby(['date']).mean()
display(df_prices_mean_hung)

# mobile = 1
print('mobile=1')
df_prices = df_comp[['date', 'price']]
df_prices_mean = df_prices.groupby(['date']).mean()
display(df_prices_mean)

# On a bien une petite différence du prix moyen entre mobile=0 et mobile=1 pour les derniers jours avant réservation
# Out:
# mobile=0
#       price_hung
# date
# 1     158.008380
# 2     153.341317
# 3     184.878788
# 4     160.734234
# 5     203.387097
# 8     155.539062
# 9     177.165414
# 10    146.120690
# 11    191.557576
# 13    168.959799
# 14    101.256757
# 15    180.930108
# 16    181.570946
# 18    169.244328
# 20    171.910256
# 22    125.715517
# 24    129.479167
# 30    124.806818
# 36    121.786885
# 37     73.622642
# 39    119.593496
# 40     91.876404
# 41    123.283019
# mobile=1
#            price
# date
# 1     156.162011
# 2     150.625749
# 3     184.878788
# 4     160.734234
# 5     203.387097
# 8     155.539062
# 9     177.165414
# 10    146.120690
# 11    191.557576
# 13    168.959799
# 14    101.256757
# 15    180.930108
# 16    181.570946
# 18    169.244328
# 20    171.910256
# 22    125.715517
# 24    129.479167
# 30    124.806818
# 36    121.786885
# 37     73.622642
# 39    119.593496
# 40     91.876404
# 41    123.283019

# %% [markdown]
# # Distribution du prix selon le mobile

# %%
plt.figure(1)
plt.scatter(df_comp['date'], df_comp['price'])
plt.title('Distribution du prix par date selon mobile=1')

plt.figure(2)
plt.scatter(df_comp['date'], df_comp['price_hung'])
plt.title('Distribution du prix par date selon mobile=0')

plt.show()

# %%
plt.figure(1)
plt.plot(df_prices_mean['price'])
plt.title('Distribution du prix moyen par date selon mobile=1')

plt.figure(2)
plt.plot(df_prices_mean_hung['price_hung'])
plt.title('Distribution du prix moyen par date selon mobile=0')

plt.show()

# %%
df_hung_price = df_comp[['hotel_id', 'date', 'price', 'price_hung']]
display(df_hung_price)
# Out:
#       hotel_id  date  price  price_hung
# 0          714    30     70          70
# 1          112    30     70          70
# 2          486    30    157         157
# 3          642    30     66          66
# 4          751    30    200         200
# ...        ...   ...    ...         ...
# 8362       141     1     85          85
# 8363       181     1    100         100
# 8364       923     1     53          53
# 8365       862     1     74          74
# 8366       683     1     85          85
#
# [8367 rows x 4 columns]

# %%
df_bis = pd.DataFrame(columns=['date', 'price_mean', 'price_mean_hung'])
df_bis['date'] = df_comp['date'].unique()
df_bis['price_mean'] = df_prices_mean['price']
df_bis['price_mean_hung'] = df_prices_mean_hung['price_hung']
df_bis.set_index('date')
df_bis.reset_index(drop=True, inplace=True)
display(df_bis)
# Out:
#     date  price_mean  price_mean_hung
# 0     30         NaN              NaN
# 1     37  156.162011       158.008380
# 2     15  150.625749       153.341317
# 3     14  184.878788       184.878788
# 4     39  160.734234       160.734234
# 5     10  203.387097       203.387097
# 6      2         NaN              NaN
# 7      3         NaN              NaN
# 8      4  155.539062       155.539062
# 9     18  177.165414       177.165414
# 10    24  146.120690       146.120690
# 11    22  191.557576       191.557576
# 12    13         NaN              NaN
# 13    11  168.959799       168.959799
# 14    41  101.256757       101.256757
# 15     8  180.930108       180.930108
# 16     9  181.570946       181.570946
# 17    36         NaN              NaN
# 18    40  169.244328       169.244328
# 19    20         NaN              NaN
# 20    16  171.910256       171.910256
# 21     1         NaN              NaN
# 22     5  125.715517       125.715517
